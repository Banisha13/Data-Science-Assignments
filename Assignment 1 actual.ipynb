# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
car_df = pd.read_csv("Cars.csv")

# %%
car_df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
car_df.dtypes
# Out:
# HP       int64
# MPG    float64
# VOL      int64
# SP     float64
# WT     float64
# dtype: object

# %%
from scipy import stats

# %%
1-stats.norm.cdf( 38,
loc=car_df.MPG.mean(),
scale=car_df.MPG.std()) # P(MPG>38)
# Out:
# 0.34759392515827137

# %%
stats.norm.cdf( 40,
loc=car_df.MPG.mean(),
scale=car_df.MPG.std()) # P(MPG<40)
# Out:
# 0.7293498762151609

# %%
X=1-stats.norm.cdf( 20,
loc=car_df.MPG.mean(),
scale=car_df.MPG.std()) # P(MPG>20) greater than 20

# %%
X
# Out:
# 0.9428762236788408

# %%
Y=stats.norm.cdf( 50,
loc=car_df.MPG.mean(),
scale=car_df.MPG.std()) # P(MPG<50) less than 50

# %%
Y
# Out:
# 0.9559926932893639

# %%
Z=Y-X

# %%
Z # P (20<MPG<50)
# Out:
# 0.01311646961052304

# %%
import seaborn as sns

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   HP      81 non-null     int64
#  1   MPG     81 non-null     float64
#  2   VOL     81 non-null     int64
#  3   SP      81 non-null     float64
#  4   WT      81 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.3 KB

# %%
car_df.isnull().sum()
# Out:
# HP     0
# MPG    0
# VOL    0
# SP     0
# WT     0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
car_df['MPG'].boxplot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 car_df['MPG'].boxplot()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'boxplot'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
car_df = pd.read_csv("Cars.csv")

# %%
sns.histplot(car_df['MPG'], kde=True)
plt.title('Histogram of MPG')
plt.show()

# %%
# Plot a probability plot (Q-Q plot)
stats.probplot(car_df['MPG'], plot=plt)
plt.title('Q-Q Plot of MPG')
plt.show()

# %%
data2 = pd.read_csv('wc-at.csv')

# %%
data2.head()
# Out:
#    Waist     AT
# 0  74.75  25.72
# 1  72.60  25.89
# 2  81.80  42.60
# 3  83.95  42.80
# 4  74.65  29.84

# %%
data2.isnull().sum()
# Out:
# Waist    0
# AT       0
# dtype: int64

# %%
sns.histplot(data2['Waist'], kde=True)
plt.title('Histogram of Waist')
plt.show()

# %%
# Plot a probability plot (Q-Q plot)
stats.probplot(data2['Waist'], plot=plt)
plt.title('Q-Q Plot of Waist')
plt.show()

# %%
sns.histplot(data2['AT'], kde=True)
plt.title('Histogram of AT')
plt.show()

# %%
# Plot a probability plot (Q-Q plot)
stats.probplot(data2['AT'], plot=plt)
plt.title('Q-Q Plot of AT')
plt.show()
